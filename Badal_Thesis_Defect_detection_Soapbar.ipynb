# %% [markdown]
# <a href="https://colab.research.google.com/github/Badalnishant1/visuial-inspection/blob/master/Badal_Thesis_Defect_detection_Soapbar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %% [markdown]
# Hi,
#
# How to deploy the code.
#
# 1) Connect the google drive
#
# 2) Clone yolov5
#
# 3) Change Dir to YOLOV5
#
# 4) Pip install r- requirements file.
#
# 5) Load your Data Set as Shown Format: Data folder contains all image files and .txt files Lammblg tool
#
#      data:
#          (images)img1.png, img2.png . . . .img.n, (Annotates) img1.txt,img2.txt
#
#
# 6) Then Split the data set as:
#
#        dataset:
#                image/
#                     train(Contains Training Images 80%)
#                     val(Contain Val Images 20%)
#                 labels
#                     train(img.txt files of all training iamges)
#                     val(img.txt files of all val images)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15598, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 15598 (delta 98), reused 119 (delta 57), pack-reused 15393
# Receiving objects: 100% (15598/15598), 14.64 MiB | 20.56 MiB/s, done.
# Resolving deltas: 100% (10622/10622), done.

# %%
pwd
# Out:
# '/content'

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !cp -r /content/drive/MyDrive/Ofc/dataset/Combined_Data /content/sample_data/data_set

# %%
import os
from random import choice
import shutil

#arrays to store file names
imgs =[]
xmls =[]

#setup dir names
trainPath = '/content/sample_data/data_set/data/images/train'
valPath = '/content/sample_data/data_set/data/images/val'
crsPath = '/content/sample_data/data_set/Combined_Data' #dir where images and annotations stored

#setup ratio (val ratio = rest of the files in origin dir after splitting into train and test)
train_ratio = 0.8
val_ratio = 0.2


#total count of imgs
totalImgCount = len(os.listdir(crsPath))/2

#soring files to corresponding arrays
for (dirname, dirs, files) in os.walk(crsPath):
    for filename in files:
        if filename.endswith('.txt'):
            xmls.append(filename)
        else:
            imgs.append(filename)


#counting range for cycles
countForTrain = int(len(imgs)*train_ratio)
countForVal = int(len(imgs)*val_ratio)
print("training images are : ",countForTrain)
print("Validation images are : ",countForVal)
# Out:
# training images are :  297
# Validation images are :  74

# %%
trainimagePath = '/content/sample_data/data_set/data/images/train'
trainlabelPath = '/content/sample_data/data_set/data/labels/train'
valimagePath = '/content/sample_data/data_set/data/images/val'
vallabelPath = '/content/sample_data/data_set/data/labels/val'
#cycle for train dir
for x in range(countForTrain):

    fileJpg = choice(imgs) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))
    shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
    shutil.copy(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))


    #remove files from arrays
    imgs.remove(fileJpg)
    xmls.remove(fileXml)



#cycle for test dir   
for x in range(countForVal):

    fileJpg = choice(imgs) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
    shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
    shutil.copy(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
    
    #remove files from arrays
    imgs.remove(fileJpg)
    xmls.remove(fileXml)

#rest of files will be validation files, so rename origin dir to val dir
#os.rename(crsPath, valPath)
shutil.move(crsPath, valPath)
# Out:
# '/content/sample_data/data_set/data/images/val/Combined_Data'

# %%
# !cp -r /content/gdrive/MyDrive/Ofc/data /content/sample_data/

# %%
# !python train.py --img 1280 --batch 16 --epochs 100 --data /content/sample_data/data/dataset.yaml
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/sample_data/data/dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python train.py --img 1280 --batch 16 --epochs 30 --data /content/sample_data/data_set/data/dataset.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/sample_data/data_set/data/dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !zip -r /content/exp_b16_e100.zip /content/yolov5/runs/train/exp10
# Out:
#   adding: content/yolov5/runs/train/exp10/ (stored 0%)
#   adding: content/yolov5/runs/train/exp10/R_curve.png (deflated 14%)
#   adding: content/yolov5/runs/train/exp10/results.png (deflated 9%)
#   adding: content/yolov5/runs/train/exp10/val_batch1_pred.jpg (deflated 12%)
#   adding: content/yolov5/runs/train/exp10/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp10/weights/best.pt (deflated 10%)
#   adding: content/yolov5/runs/train/exp10/weights/last.pt (deflated 10%)
#   adding: content/yolov5/runs/train/exp10/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp10/labels.jpg (deflated 31%)
#   adding: content/yolov5/runs/train/exp10/train_batch2.jpg (deflated 21%)
#   adding: content/yolov5/runs/train/exp10/labels_correlogram.jpg (deflated 43%)
#   adding: content/yolov5/runs/train/exp10/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp10/results.csv (deflated 83%)
#   adding: content/yolov5/runs/train/exp10/P_curve.png (deflated 14%)
# ...

# %%
from google.colab import files
files.download('/content/exp_b16_e30.zip')
